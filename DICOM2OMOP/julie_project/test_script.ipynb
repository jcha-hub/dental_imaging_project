# %%
#check dicom2omop_env packages installed
# !uv pip list
# Out:
# Package            Version
# ------------------ ------------
# asttokens          3.0.1
# azure-core         1.38.3
# azure-identity     1.25.3
# certifi            2026.2.25
# cffi               2.0.0
# charset-normalizer 3.4.6
# colorama           0.4.6
# comm               0.2.3
# cryptography       46.0.5
# debugpy            1.8.20
# decorator          5.2.1
# exceptiongroup     1.3.1
# executing          2.2.1
# idna               3.11
# ipykernel          7.2.0
# ipython            8.38.0
# jedi               0.19.2
# jupyter-client     8.8.0
# jupyter-core       5.9.1
# matplotlib-inline  0.2.1
# msal               1.35.1
# msal-extensions    1.3.1
# nest-asyncio       1.6.0
# numpy              2.2.6
# packaging          26.0
# pandas             2.3.3
# parso              0.8.6
# platformdirs       4.9.4
# prompt-toolkit     3.0.52
# psutil             7.2.2
# pure-eval          0.2.3
# pyarrow            23.0.1
# pycparser          3.0
# pydicom            3.0.1
# ...

# %%
print('hello')
# Out:
# hello

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\julie\AI agent courses\dental_imaging_project_local\DICOM2OMOP\dicom2omop_env\Scripts\python.exe
